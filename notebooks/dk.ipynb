# %%
import torch

# %%
# load the model from models directory. the model is stored as state_dict

state_dict = torch.load('../models/cnn_model_hpc.pt', map_location=torch.device('cpu'))

# Display the layers and their shapes
print("Model Layers:")
print("-" * 80)
for layer_name, param in state_dict.items():
    print(f"{layer_name:50s} | Shape: {tuple(param.shape)}")
# Out:
# Model Layers:
# --------------------------------------------------------------------------------
# conv1.weight                                       | Shape: (16, 1, 3, 3)
# conv1.bias                                         | Shape: (16,)
# conv2.weight                                       | Shape: (32, 16, 3, 3)
# conv2.bias                                         | Shape: (32,)
# conv3.weight                                       | Shape: (64, 32, 3, 3)
# conv3.bias                                         | Shape: (64,)
# conv4.weight                                       | Shape: (128, 64, 3, 3)
# conv4.bias                                         | Shape: (128,)
# conv5.weight                                       | Shape: (256, 128, 3, 3)
# conv5.bias                                         | Shape: (256,)
# conv6.weight                                       | Shape: (512, 256, 3, 3)
# conv6.bias                                         | Shape: (512,)
# ...
